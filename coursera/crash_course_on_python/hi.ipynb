# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    --------- ------------------------------ 2.6/11.5 MB 13.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.8/11.5 MB 18.5 MB/s eta 0:00:01
#    ------------------------------------- -- 10.7/11.5 MB 18.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 16.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------- ----------------------- 5.2/12.6 MB 26.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.3/12.6 MB 27.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 25.8 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/4 [pytz]
#    ---------------------------------------- 0/4 [pytz]
#    ---------- ----------------------------- 1/4 [tzdata]
#    ---------- ----------------------------- 1/4 [tzdata]
#    -------------------- ------------------- 2/4 [numpy]
# ...

# %%
import pandas as pd
list_one = [1, "Adair"]
print(pd.DataFrame(list_one))
# Out:
#        0
# 0      1
# 1  Adair
